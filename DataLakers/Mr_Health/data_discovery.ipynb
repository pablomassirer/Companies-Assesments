# %% [markdown]
# ##### Descrição
#
# > Notebook para Filtrar dados do BD

# %% [markdown]
# ##### Filtering

# %%
import pandas as pd
from db_ingestao import connect_db

# %%
columns, data = connect_db('SELECT * FROM pedido')

df = pd.DataFrame(data, columns=columns)

df
# Out:
#    id_unidade  id_pedido  tipo_pedido data_pedido  vlr_pedido  \
# 0           2          1            1  1997-08-18       122.0
# 1           5          2            1  2002-12-11       111.0
# 2           3          3            2  2000-09-16       409.0
# 3           7          4            2  1990-10-12       887.0
# 4           6          5            1  2008-06-22      1008.0
# 5           4          6            2  2015-03-21       225.0
# 6           1          7            1  2000-06-14        77.0
# 7           1          8            3  1997-08-18       122.0
#
#                                     endereco_entrega  taxa_entrega  status
# 0                           USNV Green\nFPO AA 02373         11.00       3
# 1           22773 Bryan Skyway\nHowardtown, NV 40093          2.75       1
# 2          808 Walsh Highway\nMichaelhaven, IL 57239         19.25       1
# 3           9031 Coleman Roads\nJohnnystad, GU 34082         22.00       1
# ...
